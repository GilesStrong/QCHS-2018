# %% [markdown]
# # Swish-based classifier with data augmentation and stochastic weght-averaging
# - Swish activation, 4 layers, 100 neurons per layer
# - Data is augmentaed via phi rotations, and transvers and longitudinal flips
# - Model uses a running average of previous weights
# - Validation score use ensemble of 10 models weighted by loss

# %% [markdown]
# ### Import modules

# %%
# %matplotlib inline
from __future__ import division
import sys
import os
sys.path.append('../')
from Modules.Basics import *
from Modules.Class_Basics import *
# Out:
# /home/giles/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /home/giles/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Using TensorFlow backend.

# %% [markdown]
# ## Options

# %%
with open(dirLoc + 'features.pkl', 'rb') as fin:
    classTrainFeatures = pickle.load(fin)

# %%
nSplits = 10
patience = 50
maxEpochs = 200

ensembleSize = 10
ensembleMode = 'loss'

compileArgs = {'loss':'binary_crossentropy', 'optimizer':'adam'}
trainParams = {'epochs' : 1, 'batch_size' : 256, 'verbose' : 0}
modelParams = {'version':'modelSwish', 'nIn':len(classTrainFeatures), 'compileArgs':compileArgs, 'mode':'classifier'}

print ("\nTraining on", len(classTrainFeatures), "features:", [var for var in classTrainFeatures])
# Out:
# Training on 31 features: ['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis', 'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet', 'DER_prodeta_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_sum_pt', 'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality', 'DER_lep_eta_centrality', 'PRI_met_pt', 'PRI_met_sumet', 'PRI_jet_num', 'PRI_jet_all_pt', 'PRI_tau_px', 'PRI_tau_py', 'PRI_tau_pz', 'PRI_lep_px', 'PRI_lep_py', 'PRI_lep_pz', 'PRI_jet_leading_px', 'PRI_jet_leading_py', 'PRI_jet_leading_pz', 'PRI_jet_subleading_px', 'PRI_jet_subleading_py', 'PRI_jet_subleading_pz', 'PRI_met_px', 'PRI_met_py']

# %% [markdown]
# ## Import data

# %%
with open(dirLoc + 'inputPipe.pkl', 'rb') as fin:
    inputPipe = pickle.load(fin)

# %%
trainData = RotationReflectionBatch(classTrainFeatures, h5py.File(dirLoc + 'train.hdf5', "r+"),
                                    inputPipe=inputPipe, augRotMult=16)

# %% [markdown]
# ## Determine LR

# %%
lrFinder = batchLRFind(trainData, getModel, modelParams, trainParams,
                       lrBounds=[1e-5,1e-1], trainOnWeights=True, verbose=0)
# Out:
# 2 classes found, running in binary mode
# /home/giles/anaconda3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# No handles with labels found to put in legend.
# ______________________________________
# Training finished
# Cross-validation took 18.660s
# ______________________________________

# %% [markdown]
# ## Train classifier

# %%
results, histories = batchTrainClassifier(trainData, nSplits, getModel, 
                                          {**modelParams, 'compileArgs':{**compileArgs, 'lr':2e-3}},
                                          trainParams, trainOnWeights=True, maxEpochs=maxEpochs,
                                          swaStart=125, swaRenewal=-1,
                                          patience=patience, verbose=1, amsSize=250000)
# Out:
# Training using weights
# Running fold 1 / 10
# 2 classes found, running in binary mode
#
# 1 New best found: 3.8324186580732575e-05
# 2 New best found: 3.7469157104559623e-05
# 3 New best found: 3.6876136355998674e-05
# 4 New best found: 3.543037565955778e-05
# 6 New best found: 3.5032572314542355e-05
# 7 New best found: 3.4872763021548655e-05
# 8 New best found: 3.485711923319024e-05
# 9 New best found: 3.439738119348264e-05
# 11 New best found: 3.428611103207681e-05
# 12 New best found: 3.402505283530772e-05
# 14 New best found: 3.4012628727319535e-05
# 16 New best found: 3.376790851863805e-05
# 19 New best found: 3.370774209442384e-05
# 20 New best found: 3.35804229767278e-05
# 27 New best found: 3.336912276656435e-05
# 28 New best found: 3.3106097036002034e-05
# 41 New best found: 3.300400146347483e-05
# 47 New best found: 3.298249243327946e-05
# 48 New best found: 3.279903765427508e-05
# 50 New best found: 3.2782877783929946e-05
# 65 New best found: 3.268424417499816e-05
# 67 New best found: 3.264187868025979e-05
# 74 New best found: 3.2627491190936e-05
# 94 New best found: 3.253126695226105e-05
# 98 New best found: 3.250455119086954e-05
# 104 New best found: 3.244058855133024e-05
# 106 New best found: 3.243724077301324e-05
# SWA beginning
# model is 0 epochs old
# 125 swa loss 3.284072900850413e-05, default loss 3.284072900850413e-05
# model is 1 epochs old
# new model is 1 epochs old
# 126 swa loss 3.233631254252461e-05, default loss 3.257266895116075e-05
# 126 New best found: 3.233631254252461e-05
# model is 2 epochs old
# new model is 2 epochs old
# 127 swa loss 3.214402207119742e-05, default loss 3.250504008558116e-05
# 127 New best found: 3.214402207119742e-05
# model is 3 epochs old
# new model is 3 epochs old
# 128 swa loss 3.2091513115524464e-05, default loss 3.256766885649915e-05
# 128 New best found: 3.2091513115524464e-05
# model is 4 epochs old
# new model is 4 epochs old
# 129 swa loss 3.208314313660644e-05, default loss 3.270737938301272e-05
# 129 New best found: 3.208314313660644e-05
# model is 5 epochs old
# new model is 5 epochs old
# 130 swa loss 3.2064450477941e-05, default loss 3.264426856985444e-05
# 130 New best found: 3.2064450477941e-05
# model is 6 epochs old
# new model is 6 epochs old
# 131 swa loss 3.203814258981529e-05, default loss 3.2696535788666445e-05
# 131 New best found: 3.203814258981529e-05
# model is 7 epochs old
# new model is 7 epochs old
# 132 swa loss 3.20390896257448e-05, default loss 3.278792753612272e-05
# model is 8 epochs old
# new model is 8 epochs old
# 133 swa loss 3.203521778755422e-05, default loss 3.258784056869484e-05
# 133 New best found: 3.203521778755422e-05
# model is 9 epochs old
# new model is 9 epochs old
# 134 swa loss 3.203227607120931e-05, default loss 3.258650972911344e-05
# 134 New best found: 3.203227607120931e-05
# model is 10 epochs old
# new model is 10 epochs old
# 135 swa loss 3.2054988226743826e-05, default loss 3.29165085785239e-05
# model is 11 epochs old
# new model is 11 epochs old
# 136 swa loss 3.2065276659134796e-05, default loss 3.290205558854912e-05
# model is 12 epochs old
# new model is 12 epochs old
# 137 swa loss 3.2055375399553827e-05, default loss 3.250493022840945e-05
# model is 13 epochs old
# new model is 13 epochs old
# 138 swa loss 3.2046686135556315e-05, default loss 3.246360355010168e-05
# model is 14 epochs old
# new model is 14 epochs old
# 139 swa loss 3.203830921498427e-05, default loss 3.246197410500905e-05
# model is 15 epochs old
# new model is 15 epochs old
# 140 swa loss 3.203849638197394e-05, default loss 3.250507379707308e-05
# model is 16 epochs old
# new model is 16 epochs old
# 141 swa loss 3.204608376124114e-05, default loss 3.260884068369432e-05
# model is 17 epochs old
# new model is 17 epochs old
# 142 swa loss 3.2051994474676296e-05, default loss 3.305559441042328e-05
# model is 18 epochs old
# new model is 18 epochs old
# 143 swa loss 3.204933308352901e-05, default loss 3.249281423333595e-05
# model is 19 epochs old
# new model is 19 epochs old
# 144 swa loss 3.2052260764020685e-05, default loss 3.2737132968265605e-05
# model is 20 epochs old
# new model is 20 epochs old
# 145 swa loss 3.205150359848564e-05, default loss 3.2709347686609234e-05
# model is 21 epochs old
# new model is 21 epochs old
# 146 swa loss 3.2043437250972684e-05, default loss 3.233272486032045e-05
# model is 22 epochs old
# new model is 22 epochs old
# 147 swa loss 3.203905765424241e-05, default loss 3.251201085546101e-05
# model is 23 epochs old
# new model is 23 epochs old
# 148 swa loss 3.2032601898901896e-05, default loss 3.253291424439921e-05
# model is 24 epochs old
# new model is 24 epochs old
# 149 swa loss 3.202165946859929e-05, default loss 3.2453614879739155e-05
# 149 New best found: 3.202165946859929e-05
# model is 25 epochs old
# new model is 25 epochs old
# 150 swa loss 3.201618709693408e-05, default loss 3.232309290770231e-05
# 150 New best found: 3.201618709693408e-05
# model is 26 epochs old
# new model is 26 epochs old
# 151 swa loss 3.201142377440587e-05, default loss 3.253383029752658e-05
# 151 New best found: 3.201142377440587e-05
# model is 27 epochs old
# new model is 27 epochs old
# 152 swa loss 3.200545020459221e-05, default loss 3.2428580517522144e-05
# 152 New best found: 3.200545020459221e-05
# model is 28 epochs old
# new model is 28 epochs old
# 153 swa loss 3.2007076303660195e-05, default loss 3.258682629551746e-05
# model is 29 epochs old
# new model is 29 epochs old
# 154 swa loss 3.200513206440468e-05, default loss 3.284024418488672e-05
# 154 New best found: 3.200513206440468e-05
# model is 30 epochs old
# new model is 30 epochs old
# 155 swa loss 3.200596160232034e-05, default loss 3.255328578185347e-05
# model is 31 epochs old
# new model is 31 epochs old
# 156 swa loss 3.199855685006587e-05, default loss 3.2459988162496235e-05
# 156 New best found: 3.199855685006587e-05
# model is 32 epochs old
# new model is 32 epochs old
# 157 swa loss 3.1996085069417334e-05, default loss 3.2422143356145824e-05
# 157 New best found: 3.1996085069417334e-05
# model is 33 epochs old
# new model is 33 epochs old
# 158 swa loss 3.1994705304673144e-05, default loss 3.256531336542617e-05
# 158 New best found: 3.1994705304673144e-05
# model is 34 epochs old
# new model is 34 epochs old
# 159 swa loss 3.199708605026487e-05, default loss 3.294959547614317e-05
# model is 35 epochs old
# new model is 35 epochs old
# 160 swa loss 3.19986151101203e-05, default loss 3.2690953704188255e-05
# model is 36 epochs old
# new model is 36 epochs old
# 161 swa loss 3.1998294590430264e-05, default loss 3.276537811870186e-05
# model is 37 epochs old
# new model is 37 epochs old
# 162 swa loss 3.1999839457601796e-05, default loss 3.280843444999087e-05
# model is 38 epochs old
# new model is 38 epochs old
# 163 swa loss 3.199927832258734e-05, default loss 3.255664740145912e-05
# model is 39 epochs old
# new model is 39 epochs old
# 164 swa loss 3.200233988890934e-05, default loss 3.26348186491424e-05
# model is 40 epochs old
# new model is 40 epochs old
# 165 swa loss 3.200585248462234e-05, default loss 3.300856329402918e-05
# model is 41 epochs old
# new model is 41 epochs old
# 166 swa loss 3.200239436888103e-05, default loss 3.2953081365906554e-05
# model is 42 epochs old
# new model is 42 epochs old
# 167 swa loss 3.199528419008675e-05, default loss 3.2820024400737e-05
# model is 43 epochs old
# new model is 43 epochs old
# 168 swa loss 3.199508155561728e-05, default loss 3.254037656632815e-05
# model is 44 epochs old
# new model is 44 epochs old
# 169 swa loss 3.199640764666626e-05, default loss 3.279248891872598e-05
# model is 45 epochs old
# new model is 45 epochs old
# 170 swa loss 3.199810921606272e-05, default loss 3.270488206748675e-05
# model is 46 epochs old
# new model is 46 epochs old
# 171 swa loss 3.199646691640401e-05, default loss 3.231664303333567e-05
# model is 47 epochs old
# new model is 47 epochs old
# 172 swa loss 3.199763960704779e-05, default loss 3.253691747446211e-05
# model is 48 epochs old
# new model is 48 epochs old
# 173 swa loss 3.1999424333330324e-05, default loss 3.2547429209697255e-05
# model is 49 epochs old
# new model is 49 epochs old
# 174 swa loss 3.1994691086346026e-05, default loss 3.246355856011902e-05
# 174 New best found: 3.1994691086346026e-05
# model is 50 epochs old
# new model is 50 epochs old
# 175 swa loss 3.199043564879936e-05, default loss 3.282002160777827e-05
# 175 New best found: 3.199043564879936e-05
# model is 51 epochs old
# new model is 51 epochs old
# 176 swa loss 3.1988215248678005e-05, default loss 3.269261726541341e-05
# 176 New best found: 3.1988215248678005e-05
# model is 52 epochs old
# new model is 52 epochs old
# 177 swa loss 3.1989386471549595e-05, default loss 3.263039902858726e-05
# model is 53 epochs old
# new model is 53 epochs old
# 178 swa loss 3.199024186805119e-05, default loss 3.267771812217985e-05
# model is 54 epochs old
# new model is 54 epochs old
# 179 swa loss 3.199092401170931e-05, default loss 3.251810382755326e-05
# model is 55 epochs old
# new model is 55 epochs old
# 180 swa loss 3.1992030028618285e-05, default loss 3.2476255298136234e-05
# model is 56 epochs old
# new model is 56 epochs old
# 181 swa loss 3.199640053619395e-05, default loss 3.309348509018317e-05
# model is 57 epochs old
# new model is 57 epochs old
# 182 swa loss 3.19973927165688e-05, default loss 3.257077176974382e-05
# model is 58 epochs old
# new model is 58 epochs old
# 183 swa loss 3.199624718649516e-05, default loss 3.251046922379379e-05
# model is 59 epochs old
# new model is 59 epochs old
# 184 swa loss 3.199607149785605e-05, default loss 3.2652625145449694e-05
# model is 60 epochs old
# new model is 60 epochs old
# 185 swa loss 3.199657819020329e-05, default loss 3.272054483238046e-05
# model is 61 epochs old
# new model is 61 epochs old
# 186 swa loss 3.199793372388738e-05, default loss 3.2722221744738e-05
# model is 62 epochs old
# new model is 62 epochs old
# 187 swa loss 3.199976163241157e-05, default loss 3.307790148000838e-05
# model is 63 epochs old
# new model is 63 epochs old
# 188 swa loss 3.199906489591798e-05, default loss 3.255442855998916e-05
# model is 64 epochs old
# new model is 64 epochs old
# 189 swa loss 3.199928306616297e-05, default loss 3.2591476311920813e-05
# model is 65 epochs old
# new model is 65 epochs old
# 190 swa loss 3.200088908731179e-05, default loss 3.300787534086729e-05
# model is 66 epochs old
# new model is 66 epochs old
# 191 swa loss 3.199979697176414e-05, default loss 3.2374280475147765e-05
# model is 67 epochs old
# new model is 67 epochs old
# 192 swa loss 3.199800209251546e-05, default loss 3.246805047732658e-05
# model is 68 epochs old
# new model is 68 epochs old
# 193 swa loss 3.1998622230490685e-05, default loss 3.27078025591441e-05
# model is 69 epochs old
# new model is 69 epochs old
# 194 swa loss 3.199523351270204e-05, default loss 3.2472020536962915e-05
# model is 70 epochs old
# new model is 70 epochs old
# 195 swa loss 3.199453998505228e-05, default loss 3.2538575277380595e-05
# model is 71 epochs old
# new model is 71 epochs old
# 196 swa loss 3.199491468564766e-05, default loss 3.255431249546499e-05
# model is 72 epochs old
# new model is 72 epochs old
# 197 swa loss 3.1994976844739354e-05, default loss 3.261467007683015e-05
# model is 73 epochs old
# new model is 73 epochs old
# 198 swa loss 3.199647522592296e-05, default loss 3.2764119437207825e-05
# model is 74 epochs old
# new model is 74 epochs old
# 199 swa loss 3.1997314975746676e-05, default loss 3.26601044779291e-05
# model is 75 epochs old
# new model is 75 epochs old
# 200 swa loss 3.1998973194851245e-05, default loss 3.2986603638740954e-05
# model is 76 epochs old
# new model is 76 epochs old
# 201 swa loss 3.199761110396006e-05, default loss 3.267317850146267e-05
# model is 77 epochs old
# new model is 77 epochs old
# 202 swa loss 3.199641059617921e-05, default loss 3.252493750741802e-05
# model is 78 epochs old
# new model is 78 epochs old
# 203 swa loss 3.199595524470998e-05, default loss 3.2417882846381265e-05
# model is 79 epochs old
# new model is 79 epochs old
# 204 swa loss 3.199918786806287e-05, default loss 3.2896497591627676e-05
# model is 80 epochs old
# new model is 80 epochs old
# 205 swa loss 3.1999105733336986e-05, default loss 3.2705938762553546e-05
# model is 81 epochs old
# new model is 81 epochs old
# 206 swa loss 3.1996823413337504e-05, default loss 3.272204585417368e-05
# model is 82 epochs old
# new model is 82 epochs old
# 207 swa loss 3.199758680307842e-05, default loss 3.254886377214486e-05
# model is 83 epochs old
# new model is 83 epochs old
# 208 swa loss 3.19974419493339e-05, default loss 3.289111306618459e-05
# model is 84 epochs old
# new model is 84 epochs old
# 209 swa loss 3.1998864422602204e-05, default loss 3.2667356230747304e-05
# model is 85 epochs old
# new model is 85 epochs old
# 210 swa loss 3.1999744889288194e-05, default loss 3.2735610942506516e-05
# model is 86 epochs old
# new model is 86 epochs old
# 211 swa loss 3.199938536937424e-05, default loss 3.265470720760333e-05
# model is 87 epochs old
# new model is 87 epochs old
# 212 swa loss 3.199904005695252e-05, default loss 3.262108081995086e-05
# model is 88 epochs old
# new model is 88 epochs old
# 213 swa loss 3.2000342570500035e-05, default loss 3.269674051042767e-05
# model is 89 epochs old
# new model is 89 epochs old
# 214 swa loss 3.200203563965183e-05, default loss 3.2836289317728624e-05
# model is 90 epochs old
# new model is 90 epochs old
# 215 swa loss 3.2002468012596e-05, default loss 3.2729500694958236e-05
# model is 91 epochs old
# new model is 91 epochs old
# 216 swa loss 3.2003330804776386e-05, default loss 3.2603813149375524e-05
# model is 92 epochs old
# new model is 92 epochs old
# 217 swa loss 3.20041516740863e-05, default loss 3.270292590697607e-05
# model is 93 epochs old
# new model is 93 epochs old
# 218 swa loss 3.200485487410022e-05, default loss 3.27892450172542e-05
# model is 94 epochs old
# new model is 94 epochs old
# 219 swa loss 3.200638935596157e-05, default loss 3.2892734793921e-05
# model is 95 epochs old
# new model is 95 epochs old
# 220 swa loss 3.2006090339333526e-05, default loss 3.2828638501665316e-05
# model is 96 epochs old
# new model is 96 epochs old
# 221 swa loss 3.2006925626126445e-05, default loss 3.2688345907542873e-05
# model is 97 epochs old
# new model is 97 epochs old
# 222 swa loss 3.200832576016135e-05, default loss 3.275641586295858e-05
# model is 98 epochs old
# new model is 98 epochs old
# 223 swa loss 3.200990989750016e-05, default loss 3.297151467668061e-05
# model is 99 epochs old
# new model is 99 epochs old
# 224 swa loss 3.201123775957007e-05, default loss 3.299248572885653e-05
# model is 100 epochs old
# new model is 100 epochs old
# 225 swa loss 3.201308963617575e-05, default loss 3.303750495929858e-05
# model is 101 epochs old
# new model is 101 epochs old
# 226 swa loss 3.201383293923907e-05, default loss 3.3081838490267294e-05
# Early stopping after 226 epochs
# Score is: {'loss': 3.1988215248678005e-05, 'wAUC': 0.06369947413481458, 'AUC': 0.09825622554957936, 'AMS': 4.027289705734292, 'cut': 0.936424195766449}
# Fold took 316.212s
#
# Running fold 2 / 10
# 1 New best found: 3.807112197804157e-05
# 2 New best found: 3.698233170304185e-05
# 3 New best found: 3.565947342294549e-05
# 4 New best found: 3.5350277630724344e-05
# 5 New best found: 3.5007696548624754e-05
# 6 New best found: 3.4627847670041865e-05
# 7 New best found: 3.4619646573783834e-05
# 8 New best found: 3.441587189037939e-05
# 11 New best found: 3.4198781445838655e-05
# 12 New best found: 3.4145323176329996e-05
# 14 New best found: 3.3827578195879785e-05
# 15 New best found: 3.367141446152122e-05
# 16 New best found: 3.3659174627569685e-05
# 19 New best found: 3.348664328768587e-05
# 23 New best found: 3.3337691255605195e-05
# 28 New best found: 3.332774417843886e-05
# 29 New best found: 3.332399565784568e-05
# 31 New best found: 3.332280194926962e-05
# 33 New best found: 3.32121584853098e-05
# 34 New best found: 3.315365914775788e-05
# 39 New best found: 3.2925294624099606e-05
# 50 New best found: 3.270628746056352e-05
# 53 New best found: 3.2696903857718265e-05
# 62 New best found: 3.2518630376823416e-05
# 84 New best found: 3.247568255697015e-05
# 100 New best found: 3.246735624006378e-05
# 124 New best found: 3.24142090746917e-05
# SWA beginning
# model is 0 epochs old
# 125 swa loss 3.2519154544147714e-05, default loss 3.2519154544147714e-05
# model is 1 epochs old
# new model is 1 epochs old
# 126 swa loss 3.2257368370776814e-05, default loss 3.267579611257542e-05
# 126 New best found: 3.2257368370776814e-05
# model is 2 epochs old
# new model is 2 epochs old
# 127 swa loss 3.2236640914222194e-05, default loss 3.2768409975592275e-05
# 127 New best found: 3.2236640914222194e-05
# model is 3 epochs old
# new model is 3 epochs old
# 128 swa loss 3.219279928389854e-05, default loss 3.282413959549469e-05
# 128 New best found: 3.219279928389854e-05
# model is 4 epochs old
# new model is 4 epochs old
# 129 swa loss 3.214411957281482e-05, default loss 3.238818062115633e-05
# 129 New best found: 3.214411957281482e-05
# model is 5 epochs old
# new model is 5 epochs old
# 130 swa loss 3.214890204946534e-05, default loss 3.312464073326017e-05
# model is 6 epochs old
# new model is 6 epochs old
# 131 swa loss 3.2096237217294424e-05, default loss 3.245976444702845e-05
# 131 New best found: 3.2096237217294424e-05
# model is 7 epochs old
# new model is 7 epochs old
# 132 swa loss 3.2064004680183694e-05, default loss 3.2496097415766326e-05
# 132 New best found: 3.2064004680183694e-05
# model is 8 epochs old
# new model is 8 epochs old
# 133 swa loss 3.204140049105444e-05, default loss 3.2392194665752225e-05
# 133 New best found: 3.204140049105444e-05
# model is 9 epochs old
# new model is 9 epochs old
# 134 swa loss 3.200866307380515e-05, default loss 3.229342337970108e-05
# 134 New best found: 3.200866307380515e-05
# model is 10 epochs old
# new model is 10 epochs old
# 135 swa loss 3.2002782273344534e-05, default loss 3.265169935792821e-05
# 135 New best found: 3.2002782273344534e-05
# model is 11 epochs old
# new model is 11 epochs old
# 136 swa loss 3.198393601239854e-05, default loss 3.245045181125622e-05
# 136 New best found: 3.198393601239854e-05
# model is 12 epochs old
# new model is 12 epochs old
# 137 swa loss 3.198194178443449e-05, default loss 3.264346705363851e-05
# 137 New best found: 3.198194178443449e-05
# model is 13 epochs old
# new model is 13 epochs old
# 138 swa loss 3.198333784864714e-05, default loss 3.2829662391058725e-05
# model is 14 epochs old
# new model is 14 epochs old
# 139 swa loss 3.200124442373762e-05, default loss 3.29463450935709e-05
# model is 15 epochs old
# new model is 15 epochs old
# 140 swa loss 3.200762563762948e-05, default loss 3.2533854780891015e-05
# model is 16 epochs old
# new model is 16 epochs old
# 141 swa loss 3.201803496489254e-05, default loss 3.270654251271096e-05
# model is 17 epochs old
# new model is 17 epochs old
# 142 swa loss 3.202086034261967e-05, default loss 3.271498867742294e-05
# model is 18 epochs old
# new model is 18 epochs old
# 143 swa loss 3.2004039004640555e-05, default loss 3.231933894946442e-05
# model is 19 epochs old
# new model is 19 epochs old
# 144 swa loss 3.200183358537971e-05, default loss 3.273417482679388e-05
# model is 20 epochs old
# new model is 20 epochs old
# 145 swa loss 3.199988369758442e-05, default loss 3.26368737911078e-05
# model is 21 epochs old
# new model is 21 epochs old
# 146 swa loss 3.20038414434242e-05, default loss 3.275514877983526e-05
# model is 22 epochs old
# new model is 22 epochs old
# 147 swa loss 3.2005040089843476e-05, default loss 3.260149509111452e-05
# model is 23 epochs old
# new model is 23 epochs old
# 148 swa loss 3.2004965700054015e-05, default loss 3.264691034526502e-05
# model is 24 epochs old
# new model is 24 epochs old
# 149 swa loss 3.200133181948093e-05, default loss 3.294990379387261e-05
# model is 25 epochs old
# new model is 25 epochs old
# 150 swa loss 3.200857229337316e-05, default loss 3.2798060724092706e-05
# model is 26 epochs old
# new model is 26 epochs old
# 151 swa loss 3.2015024112319e-05, default loss 3.267597040221376e-05
# model is 27 epochs old
# new model is 27 epochs old
# 152 swa loss 3.2010722954664646e-05, default loss 3.2543739343728035e-05
# model is 28 epochs old
# new model is 28 epochs old
# 153 swa loss 3.201783125709536e-05, default loss 3.287535689166613e-05
# model is 29 epochs old
# new model is 29 epochs old
# 154 swa loss 3.201541866027537e-05, default loss 3.260067875872921e-05
# model is 30 epochs old
# new model is 30 epochs old
# 155 swa loss 3.2017449035458585e-05, default loss 3.285335151475115e-05
# model is 31 epochs old
# new model is 31 epochs old
# 156 swa loss 3.202418264060346e-05, default loss 3.333764964311625e-05
# model is 32 epochs old
# new model is 32 epochs old
# 157 swa loss 3.202521166347851e-05, default loss 3.248799644097005e-05
# model is 33 epochs old
# new model is 33 epochs old
# 158 swa loss 3.202677936095619e-05, default loss 3.279213507037482e-05
# model is 34 epochs old
# new model is 34 epochs old
# 159 swa loss 3.202872107792425e-05, default loss 3.2664758781068106e-05
# model is 35 epochs old
# new model is 35 epochs old
# 160 swa loss 3.202591807658437e-05, default loss 3.242112046744685e-05
# model is 36 epochs old
# new model is 36 epochs old
# 161 swa loss 3.202848363463937e-05, default loss 3.278010527966832e-05
# model is 37 epochs old
# new model is 37 epochs old
# 162 swa loss 3.2030019854038644e-05, default loss 3.270693486014408e-05
# model is 38 epochs old
# new model is 38 epochs old
# 163 swa loss 3.203127398414219e-05, default loss 3.271723996808084e-05
# model is 39 epochs old
# new model is 39 epochs old
# 164 swa loss 3.203154182731363e-05, default loss 3.291422852262065e-05
# model is 40 epochs old
# new model is 40 epochs old
# 165 swa loss 3.2034361638657285e-05, default loss 3.295984836481998e-05
# model is 41 epochs old
# new model is 41 epochs old
# 166 swa loss 3.2033461360808515e-05, default loss 3.269186175161047e-05
# model is 42 epochs old
# new model is 42 epochs old
# 167 swa loss 3.202913436852938e-05, default loss 3.253746827618804e-05
# model is 43 epochs old
# new model is 43 epochs old
# 168 swa loss 3.20316926933254e-05, default loss 3.2783640944323035e-05
# model is 44 epochs old
# new model is 44 epochs old
# 169 swa loss 3.203333586163211e-05, default loss 3.28512400365312e-05
# model is 45 epochs old
# new model is 45 epochs old
# 170 swa loss 3.203257475018834e-05, default loss 3.251463252973216e-05
# model is 46 epochs old
# new model is 46 epochs old
# 171 swa loss 3.20324297115265e-05, default loss 3.290004593529556e-05
# model is 47 epochs old
# new model is 47 epochs old
# 172 swa loss 3.202960010930539e-05, default loss 3.2575290839349985e-05
# model is 48 epochs old
# new model is 48 epochs old
# 173 swa loss 3.2025317926294604e-05, default loss 3.2501533316767456e-05
# model is 49 epochs old
# new model is 49 epochs old
# 174 swa loss 3.2029159282979114e-05, default loss 3.2953750832523076e-05
# model is 50 epochs old
# new model is 50 epochs old
# 175 swa loss 3.20331018234445e-05, default loss 3.298505219537189e-05
# model is 51 epochs old
# new model is 51 epochs old
# 176 swa loss 3.202773516975785e-05, default loss 3.250415653409117e-05
# model is 52 epochs old
# new model is 52 epochs old
# 177 swa loss 3.202709878785203e-05, default loss 3.266046449204611e-05
# model is 53 epochs old
# new model is 53 epochs old
# 178 swa loss 3.202578062138767e-05, default loss 3.260615830438643e-05
# model is 54 epochs old
# new model is 54 epochs old
# 179 swa loss 3.202297225090111e-05, default loss 3.245905072392315e-05
# model is 55 epochs old
# new model is 55 epochs old
# 180 swa loss 3.2023456092041564e-05, default loss 3.275944869243372e-05
# model is 56 epochs old
# new model is 56 epochs old
# 181 swa loss 3.202126864497535e-05, default loss 3.2410734349035394e-05
# model is 57 epochs old
# new model is 57 epochs old
# 182 swa loss 3.201590034803615e-05, default loss 3.227717153502103e-05
# model is 58 epochs old
# new model is 58 epochs old
# 183 swa loss 3.201850128025573e-05, default loss 3.303789732619214e-05
# model is 59 epochs old
# new model is 59 epochs old
# 184 swa loss 3.201910138072474e-05, default loss 3.278305654168382e-05
# model is 60 epochs old
# new model is 60 epochs old
# 185 swa loss 3.201724357771625e-05, default loss 3.2524162375472235e-05
# model is 61 epochs old
# new model is 61 epochs old
# 186 swa loss 3.201966000978879e-05, default loss 3.283817534299375e-05
# model is 62 epochs old
# new model is 62 epochs old
# 187 swa loss 3.202104286828707e-05, default loss 3.2657949086341895e-05
# Early stopping after 187 epochs
# Score is: {'loss': 3.198194178443449e-05, 'wAUC': 0.063971039190035, 'AUC': 0.10247224134443944, 'AMS': 4.161574997962077, 'cut': 0.9723586440086365}
# Fold took 251.624s
#
# Running fold 3 / 10
# 1 New best found: 3.795978115346761e-05
# 2 New best found: 3.686318214215821e-05
# 4 New best found: 3.6182752850760384e-05
# 6 New best found: 3.589907111897916e-05
# 7 New best found: 3.5287277522702196e-05
# 9 New best found: 3.49406014427758e-05
# 10 New best found: 3.456605823364564e-05
# 11 New best found: 3.4441059816837015e-05
# 14 New best found: 3.435866515498661e-05
# 15 New best found: 3.4313068767142935e-05
# 16 New best found: 3.42416960617709e-05
# 17 New best found: 3.400945719922584e-05
# 18 New best found: 3.3709512884139413e-05
# 20 New best found: 3.361502127819957e-05
# 25 New best found: 3.359466280920674e-05
# 26 New best found: 3.3481832714473907e-05
# 31 New best found: 3.346444977008721e-05
# 36 New best found: 3.3379792061331934e-05
# 41 New best found: 3.3291452745224933e-05
# 42 New best found: 3.3267010698161404e-05
# 43 New best found: 3.318863730931382e-05
# 47 New best found: 3.310242308498791e-05
# 50 New best found: 3.298065100044521e-05
# 51 New best found: 3.297895171866064e-05
# 63 New best found: 3.297047908017859e-05
# 73 New best found: 3.29077912616663e-05
# 79 New best found: 3.2796822103466326e-05
# 80 New best found: 3.2665080809474726e-05
# 105 New best found: 3.2648968780449806e-05
# 111 New best found: 3.254288623033123e-05
# SWA beginning
# model is 0 epochs old
# 125 swa loss 3.286724481446429e-05, default loss 3.286724481446429e-05
# model is 1 epochs old
# new model is 1 epochs old
# 126 swa loss 3.248433646011354e-05, default loss 3.265000299155438e-05
# 126 New best found: 3.248433646011354e-05
# model is 2 epochs old
# new model is 2 epochs old
# 127 swa loss 3.2303915870268574e-05, default loss 3.286839669669158e-05
# 127 New best found: 3.2303915870268574e-05
# model is 3 epochs old
# new model is 3 epochs old
# 128 swa loss 3.224351752491821e-05, default loss 3.290273239980693e-05
# 128 New best found: 3.224351752491821e-05
# model is 4 epochs old
# new model is 4 epochs old
# 129 swa loss 3.223983713628672e-05, default loss 3.290440642029629e-05
# 129 New best found: 3.223983713628672e-05
# model is 5 epochs old
# new model is 5 epochs old
# 130 swa loss 3.225879500834067e-05, default loss 3.28277513837072e-05
# model is 6 epochs old
# new model is 6 epochs old
# 131 swa loss 3.224472325533879e-05, default loss 3.265362834507962e-05
# model is 7 epochs old
# new model is 7 epochs old
# 132 swa loss 3.2210290793409e-05, default loss 3.277380808473478e-05
# 132 New best found: 3.2210290793409e-05
# model is 8 epochs old
# new model is 8 epochs old
# 133 swa loss 3.218638279272401e-05, default loss 3.245795015895732e-05
# 133 New best found: 3.218638279272401e-05
# model is 9 epochs old
# new model is 9 epochs old
# 134 swa loss 3.2191755303607585e-05, default loss 3.277764748193988e-05
# model is 10 epochs old
# new model is 10 epochs old
# 135 swa loss 3.2167873485289516e-05, default loss 3.261562228169301e-05
# 135 New best found: 3.2167873485289516e-05
# model is 11 epochs old
# new model is 11 epochs old
# 136 swa loss 3.215142646032551e-05, default loss 3.241506091681348e-05
# 136 New best found: 3.215142646032551e-05
# model is 12 epochs old
# new model is 12 epochs old
# 137 swa loss 3.214128090355825e-05, default loss 3.268703218036149e-05
# 137 New best found: 3.214128090355825e-05
# model is 13 epochs old
# new model is 13 epochs old
# 138 swa loss 3.214228894670713e-05, default loss 3.275910119581089e-05
# model is 14 epochs old
# new model is 14 epochs old
# 139 swa loss 3.214395493205482e-05, default loss 3.284124128907511e-05
# model is 15 epochs old
# new model is 15 epochs old
# 140 swa loss 3.215336811789801e-05, default loss 3.2909902263164335e-05
# model is 16 epochs old
# new model is 16 epochs old
# 141 swa loss 3.215100176626155e-05, default loss 3.26714897456783e-05
# model is 17 epochs old
# new model is 17 epochs old
# 142 swa loss 3.214867584706103e-05, default loss 3.258135032422592e-05
# model is 18 epochs old
# new model is 18 epochs old
# 143 swa loss 3.2140595466515195e-05, default loss 3.274426622772533e-05
# 143 New best found: 3.2140595466515195e-05
# model is 19 epochs old
# new model is 19 epochs old
# 144 swa loss 3.214253932827716e-05, default loss 3.277747076926733e-05
# model is 20 epochs old
# new model is 20 epochs old
# 145 swa loss 3.213481064793365e-05, default loss 3.267434234114796e-05
# 145 New best found: 3.213481064793365e-05
# model is 21 epochs old
# new model is 21 epochs old
# 146 swa loss 3.2121199086573995e-05, default loss 3.239781955624589e-05
# 146 New best found: 3.2121199086573995e-05
# model is 22 epochs old
# new model is 22 epochs old
# 147 swa loss 3.211764516557576e-05, default loss 3.2720547337221057e-05
# 147 New best found: 3.211764516557576e-05
# model is 23 epochs old
# new model is 23 epochs old
# 148 swa loss 3.212651780761396e-05, default loss 3.306469496952245e-05
# model is 24 epochs old
# new model is 24 epochs old
# 149 swa loss 3.212533981872857e-05, default loss 3.2576619752315474e-05
# model is 25 epochs old
# new model is 25 epochs old
# 150 swa loss 3.2118448286008446e-05, default loss 3.253193316929327e-05
# model is 26 epochs old
# new model is 26 epochs old
# 151 swa loss 3.211548651507405e-05, default loss 3.259240001015481e-05
# 151 New best found: 3.211548651507405e-05
# model is 27 epochs old
# new model is 27 epochs old
# 152 swa loss 3.210687823824608e-05, default loss 3.2733937514638784e-05
# 152 New best found: 3.210687823824608e-05
# model is 28 epochs old
# new model is 28 epochs old
# 153 swa loss 3.2105054058794826e-05, default loss 3.2662687811979796e-05
# 153 New best found: 3.2105054058794826e-05
# model is 29 epochs old
# new model is 29 epochs old
# 154 swa loss 3.209905478200149e-05, default loss 3.2381023723196314e-05
# 154 New best found: 3.209905478200149e-05
# model is 30 epochs old
# new model is 30 epochs old
# 155 swa loss 3.209726241078713e-05, default loss 3.262608802012223e-05
# 155 New best found: 3.209726241078713e-05
# model is 31 epochs old
# new model is 31 epochs old
# 156 swa loss 3.2093932254897695e-05, default loss 3.261090858478354e-05
# 156 New best found: 3.2093932254897695e-05
# model is 32 epochs old
# new model is 32 epochs old
# 157 swa loss 3.2093357229848105e-05, default loss 3.268916268600433e-05
# 157 New best found: 3.2093357229848105e-05
# model is 33 epochs old
# new model is 33 epochs old
# 158 swa loss 3.209586970532111e-05, default loss 3.2771730038763736e-05
# model is 34 epochs old
# new model is 34 epochs old
# 159 swa loss 3.2098638551672784e-05, default loss 3.2765137944015574e-05
# model is 35 epochs old
# new model is 35 epochs old
# 160 swa loss 3.2103841782531e-05, default loss 3.338730234877846e-05
# model is 36 epochs old
# new model is 36 epochs old
# 161 swa loss 3.20995336354808e-05, default loss 3.264659686800593e-05
# model is 37 epochs old
# new model is 37 epochs old
# 162 swa loss 3.209943417387278e-05, default loss 3.276214994030805e-05
# model is 38 epochs old
# new model is 38 epochs old
# 163 swa loss 3.210414331203725e-05, default loss 3.286365541685628e-05
# model is 39 epochs old
# new model is 39 epochs old
# 164 swa loss 3.209946939789013e-05, default loss 3.25941898417329e-05
# model is 40 epochs old
# new model is 40 epochs old
# 165 swa loss 3.209987593336785e-05, default loss 3.2699754919081714e-05
# model is 41 epochs old
# new model is 41 epochs old
# 166 swa loss 3.2106104159741623e-05, default loss 3.341467530691599e-05
# model is 42 epochs old
# new model is 42 epochs old
# 167 swa loss 3.210617554661499e-05, default loss 3.260043087420551e-05
# model is 43 epochs old
# new model is 43 epochs old
# 168 swa loss 3.210523633964133e-05, default loss 3.2672682047225564e-05
# model is 44 epochs old
# new model is 44 epochs old
# 169 swa loss 3.2105273440821586e-05, default loss 3.282392462373114e-05
# model is 45 epochs old
# new model is 45 epochs old
# 170 swa loss 3.2105041464247385e-05, default loss 3.282926194927736e-05
# model is 46 epochs old
# new model is 46 epochs old
# 171 swa loss 3.210542493857942e-05, default loss 3.268863476638913e-05
# model is 47 epochs old
# new model is 47 epochs old
# 172 swa loss 3.21020866459273e-05, default loss 3.2547350374362226e-05
# model is 48 epochs old
# new model is 48 epochs old
# 173 swa loss 3.209780058811713e-05, default loss 3.247454624919804e-05
# model is 49 epochs old
# new model is 49 epochs old
# 174 swa loss 3.209553744260948e-05, default loss 3.2753814956040026e-05
# model is 50 epochs old
# new model is 50 epochs old
# 175 swa loss 3.209547156110976e-05, default loss 3.290708115389169e-05
# model is 51 epochs old
# new model is 51 epochs old
# 176 swa loss 3.209636912539223e-05, default loss 3.261642792706938e-05
# model is 52 epochs old
# new model is 52 epochs old
# 177 swa loss 3.208932019351527e-05, default loss 3.2480539193925546e-05
# 177 New best found: 3.208932019351527e-05
# model is 53 epochs old
# new model is 53 epochs old
# 178 swa loss 3.208753932144802e-05, default loss 3.2569754214050154e-05
# 178 New best found: 3.208753932144802e-05
# model is 54 epochs old
# new model is 54 epochs old
# 179 swa loss 3.2087653945436227e-05, default loss 3.2702227957650226e-05
# model is 55 epochs old
# new model is 55 epochs old
# 180 swa loss 3.2086384998099845e-05, default loss 3.262679913269899e-05
# 180 New best found: 3.2086384998099845e-05
# model is 56 epochs old
# new model is 56 epochs old
# 181 swa loss 3.208269024058689e-05, default loss 3.234593507698192e-05
# 181 New best found: 3.208269024058689e-05
# model is 57 epochs old
# new model is 57 epochs old
# 182 swa loss 3.2080301648719096e-05, default loss 3.279349099919186e-05
# 182 New best found: 3.2080301648719096e-05
# model is 58 epochs old
# new model is 58 epochs old
# 183 swa loss 3.208240979792004e-05, default loss 3.269380196174549e-05
# model is 59 epochs old
# new model is 59 epochs old
# 184 swa loss 3.20824997871653e-05, default loss 3.278712431106004e-05
# model is 60 epochs old
# new model is 60 epochs old
# 185 swa loss 3.2081145596734884e-05, default loss 3.283329681364649e-05
# model is 61 epochs old
# new model is 61 epochs old
# 186 swa loss 3.207860202256306e-05, default loss 3.249761092257771e-05
# 186 New best found: 3.207860202256306e-05
# model is 62 epochs old
# new model is 62 epochs old
# 187 swa loss 3.207728102021148e-05, default loss 3.2514479193927696e-05
# 187 New best found: 3.207728102021148e-05
# model is 63 epochs old
# new model is 63 epochs old
# 188 swa loss 3.2074135244600836e-05, default loss 3.266860837182921e-05
# 188 New best found: 3.2074135244600836e-05
# model is 64 epochs old
# new model is 64 epochs old
# 189 swa loss 3.2072030074906196e-05, default loss 3.267189579761749e-05
# 189 New best found: 3.2072030074906196e-05
# model is 65 epochs old
# new model is 65 epochs old
# 190 swa loss 3.207046675120575e-05, default loss 3.284202904690667e-05
# 190 New best found: 3.207046675120575e-05
# model is 66 epochs old
# new model is 66 epochs old
# 191 swa loss 3.2066282125461774e-05, default loss 3.2671616040229164e-05
# 191 New best found: 3.2066282125461774e-05
# model is 67 epochs old
# new model is 67 epochs old
# 192 swa loss 3.206610938067642e-05, default loss 3.262210799866218e-05
# 192 New best found: 3.206610938067642e-05
# model is 68 epochs old
# new model is 68 epochs old
# 193 swa loss 3.20671811208365e-05, default loss 3.283645214028158e-05
# model is 69 epochs old
# new model is 69 epochs old
# 194 swa loss 3.2066526838352337e-05, default loss 3.269032480344039e-05
# model is 70 epochs old
# new model is 70 epochs old
# 195 swa loss 3.2063189101370855e-05, default loss 3.261594093144459e-05
# 195 New best found: 3.2063189101370855e-05
# model is 71 epochs old
# new model is 71 epochs old
# 196 swa loss 3.205950783218078e-05, default loss 3.246953409250031e-05
# 196 New best found: 3.205950783218078e-05
# model is 72 epochs old
# new model is 72 epochs old
# 197 swa loss 3.2058078112335756e-05, default loss 3.301711487688532e-05
# 197 New best found: 3.2058078112335756e-05
# model is 73 epochs old
# new model is 73 epochs old
# 198 swa loss 3.2055735484606104e-05, default loss 3.283152934611343e-05
# 198 New best found: 3.2055735484606104e-05
# model is 74 epochs old
# new model is 74 epochs old
# 199 swa loss 3.2054407098200346e-05, default loss 3.2689593777108237e-05
# 199 New best found: 3.2054407098200346e-05
# model is 75 epochs old
# new model is 75 epochs old
# 200 swa loss 3.205051015909948e-05, default loss 3.263727151057652e-05
# 200 New best found: 3.205051015909948e-05
# model is 76 epochs old
# new model is 76 epochs old
# 201 swa loss 3.2049520699005226e-05, default loss 3.272292551296362e-05
# 201 New best found: 3.2049520699005226e-05
# model is 77 epochs old
# new model is 77 epochs old
# 202 swa loss 3.204825808923401e-05, default loss 3.272835232397139e-05
# 202 New best found: 3.204825808923401e-05
# model is 78 epochs old
# new model is 78 epochs old
# 203 swa loss 3.204863025267493e-05, default loss 3.2946754958084674e-05
# model is 79 epochs old
# new model is 79 epochs old
# 204 swa loss 3.204667763522177e-05, default loss 3.257504732109203e-05
# 204 New best found: 3.204667763522177e-05
# model is 80 epochs old
# new model is 80 epochs old
# 205 swa loss 3.204510960155482e-05, default loss 3.260126640080385e-05
# 205 New best found: 3.204510960155482e-05
# model is 81 epochs old
# new model is 81 epochs old
# 206 swa loss 3.204232654920546e-05, default loss 3.2734412297846805e-05
# 206 New best found: 3.204232654920546e-05
# model is 82 epochs old
# new model is 82 epochs old
# 207 swa loss 3.204211766747771e-05, default loss 3.2895927377612734e-05
# 207 New best found: 3.204211766747771e-05
# model is 83 epochs old
# new model is 83 epochs old
# 208 swa loss 3.204147993902715e-05, default loss 3.2677837982340025e-05
# 208 New best found: 3.204147993902715e-05
# model is 84 epochs old
# new model is 84 epochs old
# 209 swa loss 3.203959202879856e-05, default loss 3.298305426659746e-05
# 209 New best found: 3.203959202879856e-05
# model is 85 epochs old
# new model is 85 epochs old
# 210 swa loss 3.2039022847008576e-05, default loss 3.274126548832101e-05
# 210 New best found: 3.2039022847008576e-05
# model is 86 epochs old
# new model is 86 epochs old
# 211 swa loss 3.203801826595387e-05, default loss 3.3149845844567406e-05
# 211 New best found: 3.203801826595387e-05
# model is 87 epochs old
# new model is 87 epochs old
# 212 swa loss 3.203819490278972e-05, default loss 3.280383986451378e-05
# model is 88 epochs old
# new model is 88 epochs old
# 213 swa loss 3.203748296741151e-05, default loss 3.2915315773461496e-05
# 213 New best found: 3.203748296741151e-05
# model is 89 epochs old
# new model is 89 epochs old
# 214 swa loss 3.203592582508685e-05, default loss 3.267985935501179e-05
# 214 New best found: 3.203592582508685e-05
# model is 90 epochs old
# new model is 90 epochs old
# 215 swa loss 3.203509610544689e-05, default loss 3.286610992973795e-05
# 215 New best found: 3.203509610544689e-05
# model is 91 epochs old
# new model is 91 epochs old
# 216 swa loss 3.20349263064017e-05, default loss 3.315473524657275e-05
# 216 New best found: 3.20349263064017e-05
# model is 92 epochs old
# new model is 92 epochs old
# 217 swa loss 3.2036328091680935e-05, default loss 3.277818409732351e-05
# model is 93 epochs old
# new model is 93 epochs old
# 218 swa loss 3.203559278451477e-05, default loss 3.2866809406230117e-05
# model is 94 epochs old
# new model is 94 epochs old
# 219 swa loss 3.203671163797882e-05, default loss 3.283731502203561e-05
# model is 95 epochs old
# new model is 95 epochs old
# 220 swa loss 3.20372961659373e-05, default loss 3.2834649006456756e-05
# model is 96 epochs old
# new model is 96 epochs old
# 221 swa loss 3.203775997031401e-05, default loss 3.254220980183751e-05
# model is 97 epochs old
# new model is 97 epochs old
# 222 swa loss 3.203686109706695e-05, default loss 3.266025404786613e-05
# model is 98 epochs old
# new model is 98 epochs old
# 223 swa loss 3.203584743435455e-05, default loss 3.264333246981531e-05
# model is 99 epochs old
# new model is 99 epochs old
# 224 swa loss 3.203723616813074e-05, default loss 3.299328778377938e-05
# model is 100 epochs old
# new model is 100 epochs old
# 225 swa loss 3.203744438372102e-05, default loss 3.289094126823083e-05
# model is 101 epochs old
# new model is 101 epochs old
# 226 swa loss 3.2036819640559915e-05, default loss 3.255998374450077e-05
# model is 102 epochs old
# new model is 102 epochs old
# 227 swa loss 3.203658797798159e-05, default loss 3.24993393911615e-05
# model is 103 epochs old
# new model is 103 epochs old
# 228 swa loss 3.203756703809477e-05, default loss 3.274148794633668e-05
# model is 104 epochs old
# new model is 104 epochs old
# 229 swa loss 3.203836458469501e-05, default loss 3.2985269574205274e-05
# model is 105 epochs old
# new model is 105 epochs old
# 230 swa loss 3.2039474502999436e-05, default loss 3.283401752590037e-05
# model is 106 epochs old
# new model is 106 epochs old
# 231 swa loss 3.203951886143675e-05, default loss 3.267173192364682e-05
# model is 107 epochs old
# new model is 107 epochs old
# 232 swa loss 3.203919231275484e-05, default loss 3.261920142659813e-05
# model is 108 epochs old
# new model is 108 epochs old
# 233 swa loss 3.203795582416734e-05, default loss 3.2687221451558765e-05
# model is 109 epochs old
# new model is 109 epochs old
# 234 swa loss 3.203728324575872e-05, default loss 3.280405817793628e-05
# model is 110 epochs old
# new model is 110 epochs old
# 235 swa loss 3.203658323359811e-05, default loss 3.299094757521736e-05
# model is 111 epochs old
# new model is 111 epochs old
# 236 swa loss 3.203557486570481e-05, default loss 3.3000925395639914e-05
# model is 112 epochs old
# new model is 112 epochs old
# 237 swa loss 3.2036250328633435e-05, default loss 3.2802537989482406e-05
# model is 113 epochs old
# new model is 113 epochs old
# 238 swa loss 3.20367261875238e-05, default loss 3.33002209575322e-05
# model is 114 epochs old
# new model is 114 epochs old
# 239 swa loss 3.20369963204923e-05, default loss 3.2756030273393875e-05
# model is 115 epochs old
# new model is 115 epochs old
# 240 swa loss 3.203660302781175e-05, default loss 3.314605614886145e-05
# model is 116 epochs old
# new model is 116 epochs old
# 241 swa loss 3.203731959707819e-05, default loss 3.28558837903009e-05
# model is 117 epochs old
# new model is 117 epochs old
# 242 swa loss 3.203744041726052e-05, default loss 3.26678676264778e-05
# model is 118 epochs old
# new model is 118 epochs old
# 243 swa loss 3.203953602013757e-05, default loss 3.3358612603225595e-05
# model is 119 epochs old
# new model is 119 epochs old
# 244 swa loss 3.2039762178234645e-05, default loss 3.3152013615221374e-05
# model is 120 epochs old
# new model is 120 epochs old
# 245 swa loss 3.203827932723735e-05, default loss 3.2974461689266116e-05
# model is 121 epochs old
# new model is 121 epochs old
# 246 swa loss 3.20387900413151e-05, default loss 3.303874696970478e-05
# model is 122 epochs old
# new model is 122 epochs old
# 247 swa loss 3.203861541451267e-05, default loss 3.2904731829687706e-05
# model is 123 epochs old
# new model is 123 epochs old
# 248 swa loss 3.203806004688702e-05, default loss 3.274530728087863e-05
# model is 124 epochs old
# new model is 124 epochs old
# 249 swa loss 3.2036314998741104e-05, default loss 3.285880822729572e-05
# model is 125 epochs old
# new model is 125 epochs old
# 250 swa loss 3.203665139390193e-05, default loss 3.324893815395801e-05
# model is 126 epochs old
# new model is 126 epochs old
# 251 swa loss 3.203579896691193e-05, default loss 3.279760841582355e-05
# model is 127 epochs old
# new model is 127 epochs old
# 252 swa loss 3.203610784151668e-05, default loss 3.313420629384735e-05
# model is 128 epochs old
# new model is 128 epochs old
# 253 swa loss 3.2035933911440465e-05, default loss 3.329751190250695e-05
# model is 129 epochs old
# new model is 129 epochs old
# 254 swa loss 3.2034759060123654e-05, default loss 3.2885388913124125e-05
# 254 New best found: 3.2034759060123654e-05
# model is 130 epochs old
# new model is 130 epochs old
# 255 swa loss 3.2034851862559684e-05, default loss 3.2813142005594315e-05
# model is 131 epochs old
# new model is 131 epochs old
# 256 swa loss 3.203434659562242e-05, default loss 3.3056108930925014e-05
# 256 New best found: 3.203434659562242e-05
# model is 132 epochs old
# new model is 132 epochs old
# 257 swa loss 3.2033949637307284e-05, default loss 3.281241875997866e-05
# 257 New best found: 3.2033949637307284e-05
# model is 133 epochs old
# new model is 133 epochs old
# 258 swa loss 3.203293276031142e-05, default loss 3.282987412973027e-05
# 258 New best found: 3.203293276031142e-05
# model is 134 epochs old
# new model is 134 epochs old
# 259 swa loss 3.2032218391264126e-05, default loss 3.284594184851868e-05
# 259 New best found: 3.2032218391264126e-05
# model is 135 epochs old
# new model is 135 epochs old
# 260 swa loss 3.203169655889956e-05, default loss 3.2929334951951594e-05
# 260 New best found: 3.203169655889956e-05
# model is 136 epochs old
# new model is 136 epochs old
# 261 swa loss 3.203199818566857e-05, default loss 3.29751895198118e-05
# model is 137 epochs old
# new model is 137 epochs old
# 262 swa loss 3.203163711883263e-05, default loss 3.293433124663483e-05
# 262 New best found: 3.203163711883263e-05
# model is 138 epochs old
# new model is 138 epochs old
# 263 swa loss 3.2032054999331384e-05, default loss 3.308574653627549e-05
# model is 139 epochs old
# new model is 139 epochs old
# 264 swa loss 3.203263836851229e-05, default loss 3.299729035079135e-05
# model is 140 epochs old
# new model is 140 epochs old
# 265 swa loss 3.203310222632483e-05, default loss 3.3511250002804244e-05
# model is 141 epochs old
# new model is 141 epochs old
# 266 swa loss 3.2033162739809004e-05, default loss 3.2744561389138765e-05
# model is 142 epochs old
# new model is 142 epochs old
# 267 swa loss 3.2032388625247726e-05, default loss 3.272032275921954e-05
# model is 143 epochs old
# new model is 143 epochs old
# 268 swa loss 3.203260828263013e-05, default loss 3.303729548723562e-05
# model is 144 epochs old
# new model is 144 epochs old
# 269 swa loss 3.2032073153467016e-05, default loss 3.302983266005648e-05
# model is 145 epochs old
# new model is 145 epochs old
# 270 swa loss 3.203258325779315e-05, default loss 3.309771814323676e-05
# model is 146 epochs old
# new model is 146 epochs old
# 271 swa loss 3.203272342868767e-05, default loss 3.2946166137478936e-05
# model is 147 epochs old
# new model is 147 epochs old
# 272 swa loss 3.2031770194633404e-05, default loss 3.295358891230371e-05
# model is 148 epochs old
# new model is 148 epochs old
# 273 swa loss 3.203253284200335e-05, default loss 3.308537242557446e-05
# model is 149 epochs old
# new model is 149 epochs old
# 274 swa loss 3.203290471571648e-05, default loss 3.3160377583711646e-05
# model is 150 epochs old
# new model is 150 epochs old
# 275 swa loss 3.203221894005705e-05, default loss 3.328185961164339e-05
# model is 151 epochs old
# new model is 151 epochs old
# 276 swa loss 3.203174360394937e-05, default loss 3.276369850560851e-05
# model is 152 epochs old
# new model is 152 epochs old
# 277 swa loss 3.20317065974371e-05, default loss 3.2985373925541684e-05
# model is 153 epochs old
# new model is 153 epochs old
# 278 swa loss 3.2031738689532996e-05, default loss 3.3273163034361956e-05
# model is 154 epochs old
# new model is 154 epochs old
# 279 swa loss 3.203309732483399e-05, default loss 3.348158659507748e-05
# model is 155 epochs old
# new model is 155 epochs old
# 280 swa loss 3.20333358478028e-05, default loss 3.317882454830343e-05
# model is 156 epochs old
# new model is 156 epochs old
# 281 swa loss 3.203137276546798e-05, default loss 3.257844244646846e-05
# 281 New best found: 3.203137276546798e-05
# model is 157 epochs old
# new model is 157 epochs old
# 282 swa loss 3.2031285853798916e-05, default loss 3.290780088838249e-05
# 282 New best found: 3.2031285853798916e-05
# model is 158 epochs old
# new model is 158 epochs old
# 283 swa loss 3.20312587579272e-05, default loss 3.297299843723082e-05
# 283 New best found: 3.20312587579272e-05
# model is 159 epochs old
# new model is 159 epochs old
# 284 swa loss 3.203128591143526e-05, default loss 3.2951054735307355e-05
# model is 160 epochs old
# new model is 160 epochs old
# 285 swa loss 3.202967082177384e-05, default loss 3.2810853114398914e-05
# 285 New best found: 3.202967082177384e-05
# model is 161 epochs old
# new model is 161 epochs old
# 286 swa loss 3.202948173354354e-05, default loss 3.317627481021849e-05
# 286 New best found: 3.202948173354354e-05
# model is 162 epochs old
# new model is 162 epochs old
# 287 swa loss 3.2028933065219326e-05, default loss 3.323135869166659e-05
# 287 New best found: 3.2028933065219326e-05
# model is 163 epochs old
# new model is 163 epochs old
# 288 swa loss 3.2029001644205145e-05, default loss 3.3519694521472446e-05
# ...
# 4 New best found: 3.4142050888474295e-05
# 5 New best found: 3.3540447201253236e-05
# 6 New best found: 3.349809663735692e-05
# 7 New best found: 3.3473504293087564e-05
# 8 New best found: 3.327717261928385e-05
# 9 New best found: 3.308119849481981e-05
# 10 New best found: 3.2972694898737255e-05
# 11 New best found: 3.288590721246556e-05
# 13 New best found: 3.287213379223132e-05
# 17 New best found: 3.279539041546283e-05
# 18 New best found: 3.266527610116544e-05
# 21 New best found: 3.2576461813121355e-05
# 22 New best found: 3.235973994889471e-05
# 23 New best found: 3.2282956182812175e-05
# 24 New best found: 3.2219188427203024e-05
# 31 New best found: 3.2187579022202264e-05
# 34 New best found: 3.207185772992027e-05
# 37 New best found: 3.1982191759731066e-05
# 44 New best found: 3.1896247355546155e-05
# 45 New best found: 3.17378611758342e-05
# 51 New best found: 3.1732155174885935e-05
# 54 New best found: 3.17224705593272e-05
# 55 New best found: 3.1661187952354466e-05
# 64 New best found: 3.150217107528976e-05
# 71 New best found: 3.133573471316968e-05
# 84 New best found: 3.127316868861319e-05
# 114 New best found: 3.119996025666698e-05
# 116 New best found: 3.1015891400931707e-05
# SWA beginning
# model is 0 epochs old
# 125 swa loss 3.151299871217407e-05, default loss 3.151299871217407e-05
# model is 1 epochs old
# new model is 1 epochs old
# 126 swa loss 3.1256707461548105e-05, default loss 3.155526488174724e-05
# model is 2 epochs old
# new model is 2 epochs old
# 127 swa loss 3.105187791174232e-05, default loss 3.1765075981384086e-05
# model is 3 epochs old
# new model is 3 epochs old
# 128 swa loss 3.100991191353047e-05, default loss 3.169612780425615e-05
# 128 New best found: 3.100991191353047e-05
# model is 4 epochs old
# new model is 4 epochs old
# 129 swa loss 3.09765035199147e-05, default loss 3.143815527943323e-05
# 129 New best found: 3.09765035199147e-05
# model is 5 epochs old
# new model is 5 epochs old
# 130 swa loss 3.093467590624006e-05, default loss 3.156251559152655e-05
# 130 New best found: 3.093467590624006e-05
# model is 6 epochs old
# new model is 6 epochs old
# 131 swa loss 3.091740488972286e-05, default loss 3.1727317046625596e-05
# 131 New best found: 3.091740488972286e-05
# model is 7 epochs old
# new model is 7 epochs old
# 132 swa loss 3.089284332456602e-05, default loss 3.1357761188839876e-05
# 132 New best found: 3.089284332456602e-05
# model is 8 epochs old
# new model is 8 epochs old
# 133 swa loss 3.088855169434069e-05, default loss 3.1387298076660945e-05
# 133 New best found: 3.088855169434069e-05
# model is 9 epochs old
# new model is 9 epochs old
# 134 swa loss 3.086170338618677e-05, default loss 3.130277614083518e-05
# 134 New best found: 3.086170338618677e-05
# model is 10 epochs old
# new model is 10 epochs old
# 135 swa loss 3.084219859683723e-05, default loss 3.142590520575082e-05
# 135 New best found: 3.084219859683723e-05
# model is 11 epochs old
# new model is 11 epochs old
# 136 swa loss 3.0835754913508874e-05, default loss 3.124387542749579e-05
# 136 New best found: 3.0835754913508874e-05
# model is 12 epochs old
# new model is 12 epochs old
# 137 swa loss 3.0837603872352266e-05, default loss 3.1579513018903695e-05
# model is 13 epochs old
# new model is 13 epochs old
# 138 swa loss 3.0823586449410456e-05, default loss 3.114841477437181e-05
# 138 New best found: 3.0823586449410456e-05
# model is 14 epochs old
# new model is 14 epochs old
# 139 swa loss 3.082481658985965e-05, default loss 3.1472411338846597e-05
# model is 15 epochs old
# new model is 15 epochs old
# 140 swa loss 3.0823132853537436e-05, default loss 3.146432920720251e-05
# 140 New best found: 3.0823132853537436e-05
# model is 16 epochs old
# new model is 16 epochs old
# 141 swa loss 3.080913915194921e-05, default loss 3.106508496676446e-05
# 141 New best found: 3.080913915194921e-05
# model is 17 epochs old
# new model is 17 epochs old
# 142 swa loss 3.080373784186741e-05, default loss 3.1206757648346844e-05
# 142 New best found: 3.080373784186741e-05
# model is 18 epochs old
# new model is 18 epochs old
# 143 swa loss 3.078779985871453e-05, default loss 3.123458684073831e-05
# 143 New best found: 3.078779985871453e-05
# model is 19 epochs old
# new model is 19 epochs old
# 144 swa loss 3.0792816226016496e-05, default loss 3.156065167847831e-05
# model is 20 epochs old
# new model is 20 epochs old
# 145 swa loss 3.078633536405093e-05, default loss 3.1271065606426744e-05
# 145 New best found: 3.078633536405093e-05
# model is 21 epochs old
# new model is 21 epochs old
# 146 swa loss 3.0783403683849105e-05, default loss 3.150380131600587e-05
# 146 New best found: 3.0783403683849105e-05
# model is 22 epochs old
# new model is 22 epochs old
# 147 swa loss 3.0782557242474506e-05, default loss 3.1490947698292256e-05
# 147 New best found: 3.0782557242474506e-05
# model is 23 epochs old
# new model is 23 epochs old
# 148 swa loss 3.078099164668993e-05, default loss 3.137439718323173e-05
# 148 New best found: 3.078099164668993e-05
# model is 24 epochs old
# new model is 24 epochs old
# 149 swa loss 3.07828422712652e-05, default loss 3.136707105474461e-05
# model is 25 epochs old
# new model is 25 epochs old
# 150 swa loss 3.0780395285661334e-05, default loss 3.150094299867819e-05
# 150 New best found: 3.0780395285661334e-05
# model is 26 epochs old
# new model is 26 epochs old
# 151 swa loss 3.078348242783581e-05, default loss 3.161988122588249e-05
# model is 27 epochs old
# new model is 27 epochs old
# 152 swa loss 3.077097371894533e-05, default loss 3.122115962205667e-05
# 152 New best found: 3.077097371894533e-05
# model is 28 epochs old
# new model is 28 epochs old
# 153 swa loss 3.076894035919846e-05, default loss 3.1252885635565594e-05
# 153 New best found: 3.076894035919846e-05
# model is 29 epochs old
# new model is 29 epochs old
# 154 swa loss 3.077482842607866e-05, default loss 3.159881475631885e-05
# model is 30 epochs old
# new model is 30 epochs old
# 155 swa loss 3.077755423349819e-05, default loss 3.139151855219378e-05
# model is 31 epochs old
# new model is 31 epochs old
# 156 swa loss 3.077683405703792e-05, default loss 3.166322507732481e-05
# model is 32 epochs old
# new model is 32 epochs old
# 157 swa loss 3.0774472940303735e-05, default loss 3.1313943241307485e-05
# model is 33 epochs old
# new model is 33 epochs old
# 158 swa loss 3.077439853109457e-05, default loss 3.143412119596923e-05
# model is 34 epochs old
# new model is 34 epochs old
# 159 swa loss 3.0771704239787966e-05, default loss 3.127475956015552e-05
# model is 35 epochs old
# new model is 35 epochs old
# 160 swa loss 3.0768596384655e-05, default loss 3.139389726634752e-05
# 160 New best found: 3.0768596384655e-05
# model is 36 epochs old
# new model is 36 epochs old
# 161 swa loss 3.076170662471323e-05, default loss 3.1472024102843114e-05
# 161 New best found: 3.076170662471323e-05
# model is 37 epochs old
# new model is 37 epochs old
# 162 swa loss 3.07584379673334e-05, default loss 3.1211966540292304e-05
# 162 New best found: 3.07584379673334e-05
# model is 38 epochs old
# new model is 38 epochs old
# 163 swa loss 3.075359448852105e-05, default loss 3.1079082546086284e-05
# 163 New best found: 3.075359448852105e-05
# model is 39 epochs old
# new model is 39 epochs old
# 164 swa loss 3.075162027689964e-05, default loss 3.1327635038132716e-05
# 164 New best found: 3.075162027689964e-05
# model is 40 epochs old
# new model is 40 epochs old
# 165 swa loss 3.0747260666731807e-05, default loss 3.141161172681408e-05
# 165 New best found: 3.0747260666731807e-05
# model is 41 epochs old
# new model is 41 epochs old
# 166 swa loss 3.074821614269159e-05, default loss 3.138115568433786e-05
# model is 42 epochs old
# new model is 42 epochs old
# 167 swa loss 3.074883587626512e-05, default loss 3.1723702430540404e-05
# model is 43 epochs old
# new model is 43 epochs old
# 168 swa loss 3.0742758723258074e-05, default loss 3.135822166856774e-05
# 168 New best found: 3.0742758723258074e-05
# model is 44 epochs old
# new model is 44 epochs old
# 169 swa loss 3.073882968977469e-05, default loss 3.139500848505502e-05
# 169 New best found: 3.073882968977469e-05
# model is 45 epochs old
# new model is 45 epochs old
# 170 swa loss 3.073405092065313e-05, default loss 3.130592763697929e-05
# 170 New best found: 3.073405092065313e-05
# model is 46 epochs old
# new model is 46 epochs old
# 171 swa loss 3.073078437895471e-05, default loss 3.120068285732469e-05
# 171 New best found: 3.073078437895471e-05
# model is 47 epochs old
# new model is 47 epochs old
# 172 swa loss 3.0729595400473936e-05, default loss 3.113228483467424e-05
# 172 New best found: 3.0729595400473936e-05
# model is 48 epochs old
# new model is 48 epochs old
# 173 swa loss 3.072892133942886e-05, default loss 3.1378428311781594e-05
# 173 New best found: 3.072892133942886e-05
# model is 49 epochs old
# new model is 49 epochs old
# 174 swa loss 3.0728022767667954e-05, default loss 3.1471082514470406e-05
# 174 New best found: 3.0728022767667954e-05
# model is 50 epochs old
# new model is 50 epochs old
# 175 swa loss 3.072907435346508e-05, default loss 3.1295583165483024e-05
# model is 51 epochs old
# new model is 51 epochs old
# 176 swa loss 3.0727720280526384e-05, default loss 3.134711373859558e-05
# 176 New best found: 3.0727720280526384e-05
# model is 52 epochs old
# new model is 52 epochs old
# 177 swa loss 3.072316407752375e-05, default loss 3.111319189566832e-05
# 177 New best found: 3.072316407752375e-05
# model is 53 epochs old
# new model is 53 epochs old
# 178 swa loss 3.071890689686032e-05, default loss 3.173818353742917e-05
# 178 New best found: 3.071890689686032e-05
# model is 54 epochs old
# new model is 54 epochs old
# 179 swa loss 3.071672455570552e-05, default loss 3.133924972987569e-05
# 179 New best found: 3.071672455570552e-05
# model is 55 epochs old
# new model is 55 epochs old
# 180 swa loss 3.071771813412248e-05, default loss 3.1534434382105176e-05
# model is 56 epochs old
# new model is 56 epochs old
# 181 swa loss 3.0720439190558884e-05, default loss 3.165694393146407e-05
# model is 57 epochs old
# new model is 57 epochs old
# 182 swa loss 3.0720878813620905e-05, default loss 3.154938478534953e-05
# model is 58 epochs old
# new model is 58 epochs old
# 183 swa loss 3.072168822561384e-05, default loss 3.136164004362827e-05
# model is 59 epochs old
# new model is 59 epochs old
# 184 swa loss 3.072267315748709e-05, default loss 3.168241290338225e-05
# model is 60 epochs old
# new model is 60 epochs old
# 185 swa loss 3.072513434701612e-05, default loss 3.173007643981672e-05
# model is 61 epochs old
# new model is 61 epochs old
# 186 swa loss 3.072362049206178e-05, default loss 3.1297680554675584e-05
# model is 62 epochs old
# new model is 62 epochs old
# 187 swa loss 3.07239418507068e-05, default loss 3.133816470192337e-05
# model is 63 epochs old
# new model is 63 epochs old
# 188 swa loss 3.072113492922077e-05, default loss 3.14754617865321e-05
# model is 64 epochs old
# new model is 64 epochs old
# 189 swa loss 3.0719218407459045e-05, default loss 3.1531505466450725e-05
# model is 65 epochs old
# new model is 65 epochs old
# 190 swa loss 3.072169616962872e-05, default loss 3.157931044811607e-05
# model is 66 epochs old
# new model is 66 epochs old
# 191 swa loss 3.0723519044769815e-05, default loss 3.1644529066564434e-05
# model is 67 epochs old
# new model is 67 epochs old
# 192 swa loss 3.0723419692330785e-05, default loss 3.151555623419587e-05
# model is 68 epochs old
# new model is 68 epochs old
# 193 swa loss 3.0722627327667516e-05, default loss 3.1211980793696445e-05
# model is 69 epochs old
# new model is 69 epochs old
# 194 swa loss 3.072193071111745e-05, default loss 3.123409571123455e-05
# model is 70 epochs old
# new model is 70 epochs old
# 195 swa loss 3.072068945636013e-05, default loss 3.146606811386717e-05
# model is 71 epochs old
# new model is 71 epochs old
# 196 swa loss 3.072171104806887e-05, default loss 3.174955689114443e-05
# model is 72 epochs old
# new model is 72 epochs old
# 197 swa loss 3.072045420724914e-05, default loss 3.133604036969495e-05
# model is 73 epochs old
# new model is 73 epochs old
# 198 swa loss 3.071967038935302e-05, default loss 3.156560448720354e-05
# model is 74 epochs old
# new model is 74 epochs old
# 199 swa loss 3.072020305046233e-05, default loss 3.1463117156143165e-05
# model is 75 epochs old
# new model is 75 epochs old
# 200 swa loss 3.0720471290050874e-05, default loss 3.176751752784673e-05
# model is 76 epochs old
# new model is 76 epochs old
# 201 swa loss 3.072104366768736e-05, default loss 3.156561844246041e-05
# model is 77 epochs old
# new model is 77 epochs old
# 202 swa loss 3.072100839526445e-05, default loss 3.116104375403398e-05
# model is 78 epochs old
# new model is 78 epochs old
# 203 swa loss 3.072200717625123e-05, default loss 3.1556115219773874e-05
# model is 79 epochs old
# new model is 79 epochs old
# 204 swa loss 3.0722265168778206e-05, default loss 3.123473907338856e-05
# model is 80 epochs old
# new model is 80 epochs old
# 205 swa loss 3.072325843258522e-05, default loss 3.133637730321503e-05
# model is 81 epochs old
# new model is 81 epochs old
# 206 swa loss 3.072142099579681e-05, default loss 3.16639756910924e-05
# model is 82 epochs old
# new model is 82 epochs old
# 207 swa loss 3.072230058254365e-05, default loss 3.1362989493919956e-05
# model is 83 epochs old
# new model is 83 epochs old
# 208 swa loss 3.072372743270357e-05, default loss 3.157261507782993e-05
# model is 84 epochs old
# new model is 84 epochs old
# 209 swa loss 3.072410763586953e-05, default loss 3.1519225095712104e-05
# model is 85 epochs old
# new model is 85 epochs old
# 210 swa loss 3.0725614227872674e-05, default loss 3.159989325040739e-05
# model is 86 epochs old
# new model is 86 epochs old
# 211 swa loss 3.072539535457783e-05, default loss 3.1386786292227354e-05
# model is 87 epochs old
# new model is 87 epochs old
# 212 swa loss 3.0724262739483354e-05, default loss 3.1414849242902503e-05
# model is 88 epochs old
# new model is 88 epochs old
# 213 swa loss 3.072397780301098e-05, default loss 3.160690910108655e-05
# model is 89 epochs old
# new model is 89 epochs old
# 214 swa loss 3.072229768784108e-05, default loss 3.1455336404366436e-05
# model is 90 epochs old
# new model is 90 epochs old
# 215 swa loss 3.0720888543154104e-05, default loss 3.141987935681282e-05
# model is 91 epochs old
# new model is 91 epochs old
# 216 swa loss 3.07208099530616e-05, default loss 3.160404585587018e-05
# model is 92 epochs old
# new model is 92 epochs old
# 217 swa loss 3.0721356614722886e-05, default loss 3.140890889001368e-05
# model is 93 epochs old
# new model is 93 epochs old
# 218 swa loss 3.0723515388145434e-05, default loss 3.200400928273401e-05
# model is 94 epochs old
# new model is 94 epochs old
# 219 swa loss 3.0724929242886224e-05, default loss 3.158234292447004e-05
# model is 95 epochs old
# new model is 95 epochs old
# 220 swa loss 3.0725389480494495e-05, default loss 3.1634245260397605e-05
# model is 96 epochs old
# new model is 96 epochs old
# 221 swa loss 3.072534414128089e-05, default loss 3.132317152864355e-05
# model is 97 epochs old
# new model is 97 epochs old
# 222 swa loss 3.0725194395859214e-05, default loss 3.191541590526382e-05
# model is 98 epochs old
# new model is 98 epochs old
# 223 swa loss 3.072638556769613e-05, default loss 3.1654787151753594e-05
# model is 99 epochs old
# new model is 99 epochs old
# 224 swa loss 3.0725137300656895e-05, default loss 3.1490698313926397e-05
# model is 100 epochs old
# new model is 100 epochs old
# 225 swa loss 3.0723480462803065e-05, default loss 3.1429930947276116e-05
# model is 101 epochs old
# new model is 101 epochs old
# 226 swa loss 3.0723373936820646e-05, default loss 3.137792397202532e-05
# model is 102 epochs old
# new model is 102 epochs old
# 227 swa loss 3.0723504268652934e-05, default loss 3.155130188530595e-05
# model is 103 epochs old
# new model is 103 epochs old
# 228 swa loss 3.072365495981449e-05, default loss 3.174101478220247e-05
# model is 104 epochs old
# new model is 104 epochs old
# 229 swa loss 3.072453921650443e-05, default loss 3.160373782981083e-05
# Early stopping after 229 epochs
# Score is: {'loss': 3.071672455570552e-05, 'wAUC': 0.059395744305618114, 'AUC': 0.09543328616056068, 'AMS': 4.0630329581719415, 'cut': 0.9754408597946167}
# Fold took 363.136s
#
#
# ______________________________________
# Training finished
# Cross-validation took 3800.511s
# Mean loss = 3.18e-05 +- 2e-07
# Mean wAUC = 0.0633 +- 0.0008
# Mean AUC = 0.0985 +- 0.0009
# Mean AMS = 4.04 +- 0.07
# Mean cut = 0.97 +- 0.006
# ______________________________________

# %% [markdown]
# Once SWA is activated at epoch 125, we find that the validation loss goes through a rapid decrease followed by a plateau with large suppression of the statistical fluctuations.
#
# Comparing to 5_Model_Data_Augmentation the metrics are mostly the same, except for the AMS which moves from3.98 to 4.04.

# %% [markdown]
# ## Construct ensemble

# %%
with open('train_weights/resultsFile.pkl', 'rb') as fin:   
    results = pickle.load(fin)

# %%
ensemble, weights = assembleEnsemble(results, ensembleSize, ensembleMode, compileArgs)
# Out:
# Choosing ensemble by loss
# Model 0 is 6 with loss = 3.056904335753643e-05
# Model 1 is 9 with loss = 3.071672455570552e-05
# Model 2 is 3 with loss = 3.120919069624506e-05
# Model 3 is 4 with loss = 3.186284687035368e-05
# Model 4 is 1 with loss = 3.198194178443449e-05
# Model 5 is 0 with loss = 3.1988215248678005e-05
# Model 6 is 2 with loss = 3.202857282279059e-05
# Model 7 is 7 with loss = 3.212407101093995e-05
# Model 8 is 5 with loss = 3.249272352986736e-05
# Model 9 is 8 with loss = 3.2645716380682534e-05

# %% [markdown]
# ## Response on validation data with TTA

# %%
valData = RotationReflectionBatch(classTrainFeatures, h5py.File(dirLoc + 'val.hdf5', "r+"), inputPipe=inputPipe,
                                  rotate = True, reflect = True, augRotMult=8)

# %%
batchEnsemblePredict(ensemble, weights, valData, ensembleSize=ensembleSize, verbose=1)
# Out:
# Predicting batch 1 out of 10
# Prediction took 0.01391659113280475s per sample
#
# Predicting batch 2 out of 10
# Prediction took 0.012305215643905102s per sample
#
# Predicting batch 3 out of 10
# Prediction took 0.0121675153426826s per sample
#
# Predicting batch 4 out of 10
# Prediction took 0.012166589914634823s per sample
#
# Predicting batch 5 out of 10
# Prediction took 0.012019737253896892s per sample
#
# Predicting batch 6 out of 10
# Prediction took 0.011995233291387557s per sample
#
# Predicting batch 7 out of 10
# Prediction took 0.012182317556254567s per sample
#
# Predicting batch 8 out of 10
# Prediction took 0.011865544037148356s per sample
#
# Predicting batch 9 out of 10
# Prediction took 0.012033153799176216s per sample
#
# Predicting batch 10 out of 10
# Prediction took 0.012129837618768215s per sample

# %%
print('Testing ROC AUC: unweighted {}, weighted {}'.format(roc_auc_score(getFeature('targets', valData.source), getFeature('pred', valData.source)),
                                                           roc_auc_score(getFeature('targets', valData.source), getFeature('pred', valData.source), sample_weight=getFeature('weights', valData.source))))
# Out:
# Testing ROC AUC: unweighted 0.9032920169789936, weighted 0.9360693746679931

# %%
amsScanSlow(convertToDF(valData.source))
# Out:
# 50000 candidates loaded
# (3.9942355961600824, 0.96019024)

# %%
# %%time
bootstrapMeanAMS(convertToDF(valData.source), N=512)
# Out:
# 50000 candidates loaded
#
# Mean AMS=4.0+-0.2, at mean cut of 0.961+-0.008
# Exact mean cut 0.9606163307325915, corresponds to AMS of 3.9670679002860356
# CPU times: user 2.58 s, sys: 15.1 s, total: 17.6 s
# Wall time: 2min 9s
# (4.0, 0.961)

# %% [markdown]
# In the validation metrics we also find improvement over 5_Model_Data_Augmentation: overallAMS moves from 3.97 to 3.99, and AMS corresponding to mean cut increases to 3.97 from 3.91.

# %% [markdown]
# # Test scoring

# %%
testData = RotationReflectionBatch(classTrainFeatures, h5py.File(dirLoc + 'testing.hdf5', "r+"), inputPipe=inputPipe,
                                   rotate = True, reflect = True, augRotMult=8)

# %%
# %%time
batchEnsemblePredict(ensemble, weights, testData, ensembleSize=ensembleSize, verbose=1)
# Out:
# Predicting batch 1 out of 10
# Prediction took 0.011936514278721402s per sample
#
# Predicting batch 2 out of 10
# Prediction took 0.01206147660294717s per sample
#
# Predicting batch 3 out of 10
# Prediction took 0.012110572331551123s per sample
#
# Predicting batch 4 out of 10
# Prediction took 0.012047166942347858s per sample
#
# Predicting batch 5 out of 10
# Prediction took 0.01204522031410174s per sample
#
# Predicting batch 6 out of 10
# Prediction took 0.012004600540413099s per sample
#
# Predicting batch 7 out of 10
# Prediction took 0.01202152247525413s per sample
#
# Predicting batch 8 out of 10
# Prediction took 0.012035000745901329s per sample
#
# Predicting batch 9 out of 10
# Prediction took 0.01231693161666732s per sample
#
# Predicting batch 10 out of 10
# Prediction took 0.012164079189165072s per sample
#
# CPU times: user 2h, sys: 10min 39s, total: 2h 10min 39s
# Wall time: 1h 50min 40s

# %%
scoreTestOD(testData.source, 0.9606163307325915)
# Out:
# Public:Private AMS: 3.6798281799107344 : 3.7847099714589465
# (3.6798281799107344, 3.7847099714589465)

# %% [markdown]
# Unfortunately, applying the cut to the test data shows an improvement in the public score (3.65->3.68) but a large decrease in private score (3.82->3.79)

# %% [markdown]
# # Save/Load

# %%
name = "weights/Swish_SWA-125"

# %%
saveEnsemble(name, ensemble, weights, compileArgs, overwrite=1)

# %%
ensemble, weights, compileArgs, _, _ = loadEnsemble(name)
